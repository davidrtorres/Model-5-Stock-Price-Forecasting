# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.preprocessing import MinMaxScaler

import pandas_datareader.data as web

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

import warnings
warnings.filterwarnings('ignore')

# %%
#df = pd.read_csv('data/apple_2012_1_1-2019_12_17.csv', parse_dates=True, index_col=[0])

#Get the stock quote 
df = web.DataReader('DAL', data_source='yahoo', start='2012-01-01', end='2019-12-17')

# %%
df.head()
# Out:
#             High   Low  Open  Close      Volume  Adj Close
# Date
# 2012-01-03  8.30  8.02  8.23   8.04   7093200.0   7.141504
# 2012-01-04  8.14  7.83  8.03   8.01   7412900.0   7.114857
# 2012-01-05  8.35  7.87  8.03   8.33  10509800.0   7.399095
# 2012-01-06  8.43  8.24  8.26   8.32   6683300.0   7.390213
# 2012-01-09  8.50  8.26  8.34   8.28   9015700.0   7.354685

# %%
df.shape
# Out:
# (2003, 6)

# %%
plt.figure(figsize=(12,8))
plt.plot(df['Close'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
# Out:
# Text(0, 0.5, 'Close Price USD ($)')

# %%
#df = df.diff().dropna() #zip_df[11226].diff().dropna()

# %%
dataset = df['Close']
# dataset = data.values

# %%
def preprocessing(df,percentage):
    training_data_len = int(np.round(len(df) * percentage))
    dataset = pd.DataFrame(df)
    scaler = MinMaxScaler(feature_range = (0, 1))
    scaled_data = scaler.fit_transform(dataset)
    return training_data_len, dataset, scaler, scaled_data

# %%
training_data_len, dataset, scaler, scaled_data = preprocessing(dataset, percentage=.8)

# %%
#training_data_len = int(np.round(len(dataset) * .8))

# %%
training_data_len
# Out:
# 1602

# %%
#dataset = pd.DataFrame(dataset)

# %%
# from sklearn.preprocessing import MinMaxScaler

# scaler = MinMaxScaler(feature_range = (0, 1))
# scaled_data = scaler.fit_transform(dataset)
# scaled_data

# %%
def create_sets(training_data_len):
    #create training data set
    train_data = scaled_data[0:training_data_len,:]
    test_data = scaled_data[training_data_len -60:,:] #to 2003 which is end of dataset
    #split data into X_train and y_train data sets
    X_train = []
    y_train = []
    #create dataset X_test and y_test data sets
    X_test = []
    y_test = dataset.iloc[training_data_len:, :]


    for i in range(60, len(train_data)):
        X_train.append(train_data[i-60:i])
        y_train.append(train_data[i,0]) #will contain 61st value which will be at position 60
        if i <=61:
            print(X_train)
            print(y_train)
            print()

    for i in range(60, len(test_data)):
        X_test.append(test_data[i-60:i,0]) 
        
    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = create_sets(training_data_len)
# Out:
# [array([[0.00054397],
#        [0.        ],
#        [0.00580235],
#        [0.00562102],
#        [0.00489573],
#        [0.00471442],
#        [0.01087941],
#        [0.01559383],
#        [0.01523119],
#        [0.01305529],
#        [0.01650045],
#        [0.02393472],
#        [0.02538531],
#        [0.02320942],
#        [0.02484134],
#        [0.03535811],
#        [0.03916591],
#        [0.04315503],
#        [0.05004534],
#        [0.04605621],
#        [0.05240253],
#        [0.05602901],
#        [0.05965548],
#        [0.05403444],
#        [0.05367181],
#        [0.05403444],
#        [0.05639165],
#        [0.05222122],
#        [0.05693562],
#        [0.05312782],
#        [0.05113327],
#        [0.05294651],
#        [0.05113327],
#        [0.03699003],
#        [0.03481414],
#        [0.03046236],
#        [0.02756119],
#        [0.0299184 ],
#        [0.03427016],
#        [0.03263826],
#        [0.02955576],
#        [0.03191297],
#        [0.03009973],
#        [0.02447868],
#        [0.02466001],
#        [0.02647326],
#        [0.02466001],
#        [0.02139618],
#        [0.02357208],
#        [0.02339075],
#        [0.02937443],
#        [0.02175884],
#        [0.02357208],
#        [0.02756119],
#        [0.03136899],
#        [0.02756119],
#        [0.0291931 ],
#        [0.03390752],
#        [0.03263826],
#        [0.0360834 ]])]
# [0.03735266509866353]
#
# [array([[0.00054397],
#        [0.        ],
#        [0.00580235],
#        [0.00562102],
#        [0.00489573],
#        [0.00471442],
#        [0.01087941],
#        [0.01559383],
#        [0.01523119],
#        [0.01305529],
#        [0.01650045],
#        [0.02393472],
#        [0.02538531],
#        [0.02320942],
#        [0.02484134],
#        [0.03535811],
#        [0.03916591],
#        [0.04315503],
#        [0.05004534],
#        [0.04605621],
#        [0.05240253],
#        [0.05602901],
#        [0.05965548],
#        [0.05403444],
#        [0.05367181],
#        [0.05403444],
#        [0.05639165],
#        [0.05222122],
#        [0.05693562],
#        [0.05312782],
#        [0.05113327],
#        [0.05294651],
#        [0.05113327],
#        [0.03699003],
#        [0.03481414],
#        [0.03046236],
#        [0.02756119],
#        [0.0299184 ],
#        [0.03427016],
#        [0.03263826],
#        [0.02955576],
#        [0.03191297],
#        [0.03009973],
#        [0.02447868],
#        [0.02466001],
#        [0.02647326],
#        [0.02466001],
#        [0.02139618],
#        [0.02357208],
#        [0.02339075],
#        [0.02937443],
#        [0.02175884],
#        [0.02357208],
#        [0.02756119],
#        [0.03136899],
#        [0.02756119],
#        [0.0291931 ],
#        [0.03390752],
#        [0.03263826],
#        [0.0360834 ]]), array([[0.        ],
#        [0.00580235],
#        [0.00562102],
#        [0.00489573],
#        [0.00471442],
#        [0.01087941],
#        [0.01559383],
#        [0.01523119],
#        [0.01305529],
#        [0.01650045],
#        [0.02393472],
#        [0.02538531],
#        [0.02320942],
#        [0.02484134],
#        [0.03535811],
#        [0.03916591],
#        [0.04315503],
#        [0.05004534],
#        [0.04605621],
#        [0.05240253],
#        [0.05602901],
#        [0.05965548],
#        [0.05403444],
#        [0.05367181],
#        [0.05403444],
#        [0.05639165],
#        [0.05222122],
#        [0.05693562],
#        [0.05312782],
#        [0.05113327],
#        [0.05294651],
#        [0.05113327],
#        [0.03699003],
#        [0.03481414],
#        [0.03046236],
#        [0.02756119],
#        [0.0299184 ],
#        [0.03427016],
#        [0.03263826],
#        [0.02955576],
#        [0.03191297],
#        [0.03009973],
#        [0.02447868],
#        [0.02466001],
#        [0.02647326],
#        [0.02466001],
#        [0.02139618],
#        [0.02357208],
#        [0.02339075],
#        [0.02937443],
#        [0.02175884],
#        [0.02357208],
#        [0.02756119],
#        [0.03136899],
#        [0.02756119],
#        [0.0291931 ],
#        [0.03390752],
#        [0.03263826],
#        [0.0360834 ],
#        [0.03735267]])]
# [0.03735266509866353, 0.03463281705572949]

# %%
"""
61st value we want model to predict
"""

# #create training data set
# train_data = scaled_data[0:training_data_len,:]
# test_data = scaled_data[training_data_len -60:,:] #to 2003 which is end of dataset
# #split data into X_train and y_train data sets
# X_train = []
# y_train = []
# #create dataset X_test and y_test data sets
# X_test = []
# y_test = dataset.iloc[training_data_len:, :]


# for i in range(60, len(train_data)):
#     X_train.append(train_data[i-60:i])
#     y_train.append(train_data[i,0]) #will contain 61st value which will be at position 60
#     if i <=61:
#         print(X_train)
#         print(y_train)
#         print()
        
# for i in range(60, len(test_data)):
#     X_test.append(test_data[i-60:i,0])
# Out:
# '\n61st value we want model to predict\n'

# %%
#convert X_train and y_train to numpy array
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
X_train
# Out:
# array([[[5.43966150e-04],
#         [0.00000000e+00],
#         [5.80235171e-03],
#         ...,
#         [3.39075231e-02],
#         [3.26382630e-02],
#         [3.60834050e-02]],
#
#        [[0.00000000e+00],
#         [5.80235171e-03],
#         [5.62102390e-03],
#         ...,
#         [3.26382630e-02],
#         [3.60834050e-02],
#         [3.73526651e-02]],
#
#        [[5.80235171e-03],
#         [5.62102390e-03],
#         [4.89572994e-03],
#         ...,
#         [3.60834050e-02],
#         [3.73526651e-02],
#         [3.46328171e-02]],
#
#        ...,
#
#        [[8.01269281e-01],
#         [8.14868556e-01],
#         [8.13055278e-01],
#         ...,
#         [8.04351750e-01],
#         [7.90752475e-01],
#         [7.98730761e-01]],
#
#        [[8.14868556e-01],
#         [8.13055278e-01],
#         [8.06165028e-01],
#         ...,
#         [7.90752475e-01],
#         [7.98730761e-01],
#         [8.13961951e-01]],
#
#        [[8.13055278e-01],
#         [8.06165028e-01],
#         [8.18676336e-01],
#         ...,
#         [7.98730761e-01],
#         [8.13961951e-01],
#         [7.99274709e-01]]])

# %%
X_train.shape
# Out:
# (1542, 60, 1)

# %%
#reshape X_train dataset
#before it's 2D
#X_train = np.reshape(X_train,(X_train.shape[0],X_train.shape[1]))

# %%
model = Sequential()

model.add(LSTM(units = 50, return_sequences = True, input_shape=(X_train.shape[1],1)))
model.add(Dropout(0.2))

model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))

model.add(LSTM(units = 50, return_sequences = False))
model.add(Dropout(0.2))

model.add(Dense(units = 25))
model.add(Dense(units = 1))

model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_4 (LSTM)                (None, 60, 50)            10400
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 60, 50)            0
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 60, 50)            20200
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 60, 50)            0
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 25)                1275
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 26
# =================================================================
# Total params: 52,101
# Trainable params: 52,101
# Non-trainable params: 0
# _________________________________________________________________

# %%
#train the model
model.fit(X_train,y_train, epochs=50, batch_size=32 ) #,callbacks=[early_stop]
# Out:
# Epoch 1/50
# 1542/1542 [==============================] - 12s 8ms/step - loss: 0.0447
# Epoch 2/50
# 1542/1542 [==============================] - 11s 7ms/step - loss: 0.0045
# Epoch 3/50
# 1542/1542 [==============================] - 14s 9ms/step - loss: 0.0039
# Epoch 4/50
# 1542/1542 [==============================] - 11s 7ms/step - loss: 0.0033
# Epoch 5/50
# 1542/1542 [==============================] - 11s 7ms/step - loss: 0.0031
# Epoch 6/50
# 1542/1542 [==============================] - 10s 6ms/step - loss: 0.0030
# Epoch 7/50
# 1542/1542 [==============================] - 11s 7ms/step - loss: 0.0032
# Epoch 8/50
# 1542/1542 [==============================] - 10s 6ms/step - loss: 0.0027
# Epoch 9/50
# 1542/1542 [==============================] - 10s 6ms/step - loss: 0.0027
# Epoch 10/50
# 1542/1542 [==============================] - 11s 7ms/step - loss: 0.0024
# Epoch 11/50
# 1542/1542 [==============================] - 10s 7ms/step - loss: 0.0026
# Epoch 12/50
# 1542/1542 [==============================] - 10s 7ms/step - loss: 0.0022
# Epoch 13/50
# 1542/1542 [==============================] - 11s 7ms/step - loss: 0.0023
# Epoch 14/50
# 1542/1542 [==============================] - 10s 7ms/step - loss: 0.0024
# Epoch 15/50
# 1542/1542 [==============================] - 10s 7ms/step - loss: 0.0019
# Epoch 16/50
# 1542/1542 [==============================] - 12s 8ms/step - loss: 0.0019
# Epoch 17/50
# 1542/1542 [==============================] - 10s 6ms/step - loss: 0.0018
# Epoch 18/50
# 1542/1542 [==============================] - 10s 7ms/step - loss: 0.0019
# Epoch 19/50
# 1542/1542 [==============================] - 11s 7ms/step - loss: 0.0018
# Epoch 20/50
# 1542/1542 [==============================] - 10s 7ms/step - loss: 0.0019
# Epoch 21/50
# 1542/1542 [==============================] - 10s 7ms/step - loss: 0.0016
# Epoch 22/50
# 1542/1542 [==============================] - 10s 6ms/step - loss: 0.0015
# Epoch 23/50
# 1542/1542 [==============================] - 14s 9ms/step - loss: 0.0016
# Epoch 24/50
# 1542/1542 [==============================] - 10s 6ms/step - loss: 0.0015
# Epoch 25/50
# 1542/1542 [==============================] - 10s 7ms/step - loss: 0.0014
# Epoch 26/50
# 1542/1542 [==============================] - 10s 6ms/step - loss: 0.0015
# Epoch 27/50
# 1542/1542 [==============================] - 10s 6ms/step - loss: 0.0015
# Epoch 28/50
# 1542/1542 [==============================] - 10s 7ms/step - loss: 0.0015
# Epoch 29/50
# 1542/1542 [==============================] - 11s 7ms/step - loss: 0.0015
# Epoch 30/50
# 1542/1542 [==============================] - 10s 6ms/step - loss: 0.0014
# Epoch 31/50
# 1542/1542 [==============================] - 11s 7ms/step - loss: 0.0014
# Epoch 32/50
# 1542/1542 [==============================] - 13s 9ms/step - loss: 0.0012
# Epoch 33/50
# 1542/1542 [==============================] - 13s 9ms/step - loss: 0.0012
# Epoch 34/50
# 1542/1542 [==============================] - 13s 8ms/step - loss: 0.0014
# Epoch 35/50
# 1542/1542 [==============================] - 12s 8ms/step - loss: 0.0012
# Epoch 36/50
# 1542/1542 [==============================] - 12s 8ms/step - loss: 0.0012
# Epoch 37/50
# 1542/1542 [==============================] - 11s 7ms/step - loss: 0.0013
# Epoch 38/50
# 1542/1542 [==============================] - 10s 7ms/step - loss: 0.0012
# Epoch 39/50
# 1542/1542 [==============================] - 10s 6ms/step - loss: 0.0012
# Epoch 40/50
# 1542/1542 [==============================] - 10s 7ms/step - loss: 0.0012
# Epoch 41/50
# 1542/1542 [==============================] - 11s 7ms/step - loss: 0.0012
# Epoch 42/50
# 1542/1542 [==============================] - 12s 8ms/step - loss: 0.0012
# Epoch 43/50
# 1542/1542 [==============================] - 10s 6ms/step - loss: 0.0012
# Epoch 44/50
# 1542/1542 [==============================] - 10s 6ms/step - loss: 0.0012
# Epoch 45/50
# 1542/1542 [==============================] - 10s 7ms/step - loss: 0.0011
# Epoch 46/50
# 1542/1542 [==============================] - 10s 7ms/step - loss: 0.0011
# Epoch 47/50
# 1542/1542 [==============================] - 11s 7ms/step - loss: 0.0012
# Epoch 48/50
# 1542/1542 [==============================] - 12s 8ms/step - loss: 0.0011
# Epoch 49/50
# 1542/1542 [==============================] - 13s 8ms/step - loss: 0.0011
# Epoch 50/50
# 1542/1542 [==============================] - 13s 9ms/step - loss: 0.0010

# %%
#convert data to a numpy array
X_test = np.array(X_test)

# %%
X_test.shape
# Out:
# (401, 60)

# %%
#number of rows, number of timeseteps, number of features
X_test = np.reshape(X_test,(X_test.shape[0],X_test.shape[1],1))

# %%
X_test.shape
# Out:
# (401, 60, 1)

# %%
#get models predicted price values for X_test dataset
#want predcitions to contain same values as y_test dataset once we inverse_transform
#getting predcitiosn off of X_test
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions) #unscaling the values

# %%
predictions
# Out:
# array([[52.887817],
#        [53.08443 ],
#        [53.30243 ],
#        [53.461597],
#        [53.671894],
#        [53.84907 ],
#        [53.942066],
#        [54.083656],
#        [54.460133],
#        [54.761406],
#        [54.907646],
#        [54.878788],
#        [54.78538 ],
#        [54.79106 ],
#        [54.83065 ],
#        [54.806664],
#        [54.63073 ],
#        [54.44547 ],
#        [54.42061 ],
#        [54.50117 ],
#        [54.64078 ],
#        [54.822098],
#        [55.03879 ],
#        [55.196495],
#        [55.137417],
#        [54.918423],
#        [54.626236],
#        [54.217934],
#        [53.602463],
#        [52.88928 ],
#        [52.091118],
#        [51.341938],
#        [50.728348],
#        [50.35627 ],
#        [50.079044],
#        [49.92625 ],
#        [49.922882],
#        [50.139786],
#        [50.499046],
#        [50.78484 ],
#        [51.03924 ],
#        [51.248966],
#        [51.38011 ],
#        [51.48811 ],
#        [51.786167],
#        [52.240105],
#        [52.58968 ],
#        [52.789043],
#        [52.77782 ],
#        [52.614147],
#        [52.685402],
#        [53.05487 ],
#        [53.49489 ],
#        [53.946865],
#        [54.22003 ],
#        [54.33739 ],
#        [54.38966 ],
#        [54.43591 ],
#        [54.523285],
#        [54.70672 ],
#        [54.954914],
#        [55.12024 ],
#        [55.110966],
#        [55.04205 ],
#        [55.03518 ],
#        [55.12908 ],
#        [55.31203 ],
#        [55.761597],
#        [56.38659 ],
#        [56.91962 ],
#        [57.256588],
#        [57.425602],
#        [57.54506 ],
#        [57.783207],
#        [58.063263],
#        [58.299496],
#        [58.457775],
#        [58.59022 ],
#        [58.47072 ],
#        [58.055355],
#        [57.561176],
#        [57.235416],
#        [57.222496],
#        [57.331955],
#        [57.522686],
#        [57.746334],
#        [57.954308],
#        [58.094303],
#        [58.167927],
#        [58.219196],
#        [58.46035 ],
#        [58.53265 ],
#        [58.361675],
#        [58.097095],
#        [57.911716],
#        [57.821465],
#        [57.643738],
#        [57.14058 ],
#        [56.402565],
#        [55.544712],
#        [54.65142 ],
#        [53.812664],
#        [52.988754],
#        [52.139084],
#        [51.602737],
#        [51.49954 ],
#        [51.698563],
#        [52.19813 ],
#        [52.977547],
#        [53.669014],
#        [54.145477],
#        [54.488827],
#        [54.60484 ],
#        [54.27572 ],
#        [53.932972],
#        [53.668507],
#        [53.528595],
#        [53.718735],
#        [54.09406 ],
#        [54.676117],
#        [55.32538 ],
#        [55.88267 ],
#        [56.184006],
#        [56.414997],
#        [56.600395],
#        [56.723396],
#        [56.789684],
#        [56.826744],
#        [56.794052],
#        [56.66944 ],
#        [56.474464],
#        [56.309258],
#        [56.110058],
#        [55.981365],
#        [56.10313 ],
#        [56.35466 ],
#        [56.84462 ],
#        [57.520607],
#        [58.204094],
#        [59.005196],
#        [59.700966],
#        [59.72665 ],
#        [59.35005 ],
#        [58.556705],
#        [57.64725 ],
#        [56.80724 ],
#        [56.22964 ],
#        [55.596813],
#        [54.948692],
#        [54.254658],
#        [53.700905],
#        [53.234997],
#        [52.754246],
#        [52.12597 ],
#        [51.274902],
#        [50.678238],
#        [50.453415],
#        [50.48968 ],
#        [50.62618 ],
#        [50.79016 ],
#        [50.373146],
#        [49.753056],
#        [49.17606 ],
#        [48.712616],
#        [48.51763 ],
#        [48.589733],
#        [48.802517],
#        [48.94472 ],
#        [48.976765],
#        [48.879803],
#        [48.792202],
#        [48.739574],
#        [48.596443],
#        [48.403893],
#        [48.239037],
#        [48.15225 ],
#        [48.178223],
#        [48.30795 ],
#        [48.73873 ],
#        [49.253773],
#        [49.76132 ],
#        [50.224014],
#        [50.609364],
#        [50.879566],
#        [51.012905],
#        [51.039715],
#        [51.017445],
#        [50.889214],
#        [50.76176 ],
#        [50.687836],
#        [50.749233],
#        [51.006474],
#        [51.299862],
#        [51.57068 ],
#        [51.782322],
#        [51.905277],
#        [51.91087 ],
#        [51.74609 ],
#        [51.37502 ],
#        [50.83652 ],
#        [50.252224],
#        [49.862183],
#        [49.710274],
#        [49.732517],
#        [49.851917],
#        [50.19319 ],
#        [50.608856],
#        [51.024887],
#        [51.354645],
#        [51.591904],
#        [51.675106],
#        [51.657307],
#        [51.448826],
#        [51.176197],
#        [50.860497],
#        [50.47414 ],
#        [50.09562 ],
#        [49.9024  ],
#        [49.94507 ],
#        [50.317955],
#        [50.949165],
#        [52.05474 ],
#        [53.59441 ],
#        [55.217472],
#        [56.6386  ],
#        [57.64191 ],
#        [58.06546 ],
#        [58.136356],
#        [58.088818],
#        [57.97552 ],
#        [57.766357],
#        [57.611702],
#        [57.597824],
#        [57.66882 ],
#        [57.722683],
#        [57.809742],
#        [57.872013],
#        [57.749317],
#        [57.550224],
#        [57.444817],
#        [57.534958],
#        [57.6143  ],
#        [57.695408],
#        [57.78896 ],
#        [57.871326],
#        [57.853573],
#        [57.656822],
#        [57.37501 ],
#        [57.105206],
#        [56.662918],
#        [56.192646],
#        [55.779575],
#        [55.52796 ],
#        [55.37827 ],
#        [55.223713],
#        [55.13655 ],
#        [55.022133],
#        [54.87705 ],
#        [54.746864],
#        [54.623108],
#        [54.430416],
#        [54.17771 ],
#        [53.725475],
#        [53.25065 ],
#        [53.150574],
#        [53.48514 ],
#        [54.036953],
#        [54.64752 ],
#        [55.123318],
#        [55.4152  ],
#        [55.607   ],
#        [55.86489 ],
#        [56.09171 ],
#        [56.196255],
#        [56.230408],
#        [56.268482],
#        [56.268055],
#        [56.23613 ],
#        [56.201736],
#        [56.15932 ],
#        [56.18034 ],
#        [56.31715 ],
#        [56.514168],
#        [56.850967],
#        [57.350895],
#        [57.972855],
#        [58.50898 ],
#        [58.95347 ],
#        [59.211895],
#        [59.35984 ],
#        [59.525356],
#        [59.913338],
#        [60.43792 ],
#        [61.15819 ],
#        [61.773968],
#        [62.21869 ],
#        [62.218437],
#        [61.931084],
#        [61.795593],
#        [61.8873  ],
#        [61.997604],
#        [62.049778],
#        [62.08643 ],
#        [62.146263],
#        [61.999207],
#        [61.596718],
#        [61.06067 ],
#        [60.23487 ],
#        [59.45328 ],
#        [58.95629 ],
#        [58.885056],
#        [59.067783],
#        [59.231724],
#        [59.32412 ],
#        [59.125305],
#        [58.704906],
#        [58.3444  ],
#        [58.157528],
#        [58.064552],
#        [58.069515],
#        [58.128246],
#        [57.962418],
#        [57.62329 ],
#        [57.213512],
#        [56.912556],
#        [56.92647 ],
#        [57.186127],
#        [57.47195 ],
#        [57.67179 ],
#        [57.889633],
#        [58.079975],
#        [58.229374],
#        [58.396233],
#        [58.578743],
#        [58.831783],
#        [59.18101 ],
#        [59.41238 ],
#        [59.524677],
#        [59.533253],
#        [59.39163 ],
#        [59.156815],
#        [58.827637],
#        [58.486313],
#        [58.25112 ],
#        [58.213364],
#        [58.264626],
#        [58.25164 ],
#        [58.0873  ],
#        [57.477257],
#        [56.41095 ],
#        [55.333076],
#        [54.446236],
#        [53.837082],
#        [53.6084  ],
#        [53.58051 ],
#        [53.62714 ],
#        [53.691513],
#        [53.82869 ],
#        [53.94373 ],
#        [54.0279  ],
#        [54.132668],
#        [54.34064 ],
#        [54.609   ],
#        [54.751762],
#        [54.741352],
#        [54.72855 ],
#        [54.822803],
#        [55.023663],
#        [55.254215],
#        [55.41907 ],
#        [55.619312],
#        [55.951633],
#        [56.428707],
#        [56.941494],
#        [57.386364],
#        [57.68569 ],
#        [57.778088],
#        [57.71094 ],
#        [57.464855],
#        [57.143677],
#        [56.88671 ],
#        [56.77428 ],
#        [56.792324],
#        [56.70489 ],
#        [56.46467 ],
#        [56.260178],
#        [56.18751 ],
#        [56.38469 ],
#        [56.709312],
#        [57.069103],
#        [57.301056],
#        [57.22641 ],
#        [56.983143],
#        [56.672966],
#        [56.421913],
#        [56.228188],
#        [56.063103],
#        [55.874603],
#        [55.90081 ],
#        [56.12441 ],
#        [56.669033]], dtype=float32)

# %%
#evaluate model w/RMSE
rmse = np.sqrt(np.mean(predictions-y_test)**2)
rmse
# Out:
# Close    0.270659
# dtype: float64

# %%
predictions = pd.DataFrame(predictions, columns=['Predictions'])

# %%
train = dataset[:training_data_len]
valid = dataset[training_data_len:] #data from index training_data_len to

# %%
len(predictions), len(valid)
# Out:
# (401, 401)

# %%
valid.reset_index(inplace=True)

# %%
valid.head()
# Out:
#         Date      Close
# 0 2018-05-16  53.480000
# 1 2018-05-17  53.099998
# 2 2018-05-18  52.950001
# 3 2018-05-21  53.980000
# 4 2018-05-22  53.520000

# %%
predictions.head()
# Out:
#    Predictions
# 0    52.887817
# 1    53.084431
# 2    53.302429
# 3    53.461597
# 4    53.671894

# %%
valid['Prediction'] = predictions['Predictions']

# %%
valid1 = valid.set_index('Date')

# %%
valid1.head()
# Out:
#                 Close  Prediction
# Date
# 2018-05-16  53.480000   52.887817
# 2018-05-17  53.099998   53.084431
# 2018-05-18  52.950001   53.302429
# 2018-05-21  53.980000   53.461597
# 2018-05-22  53.520000   53.671894

# %%
"""
blue-data model was trainined on 
orange-actual closing stock price for rest of days
green-what model predcited values to be
"""

# train = dataset[:training_data_len]
# valid = dataset[training_data_len:] #data from index training_data_len to 
# valid['Predictions'] = predictions
plt.figure(figsize=(12,8))
plt.title('Model')
plt.xlabel('Label')
plt.ylabel('Close Price USD ($)')
plt.plot(train['Close'])
#plt.plot(valid[['Close','Predictions']])
plt.plot(valid1['Close'])
plt.plot(valid1['Prediction'])
# #valid[['Close','Predictions']].plot()
plt.legend(['Train','Valid','Predictions'],loc='lower right')

# %%
dataset.tail()
# Out:
#                 Close
# Date
# 2019-12-11  55.080002
# 2019-12-12  56.689999
# 2019-12-13  56.730000
# 2019-12-16  58.419998
# 2019-12-17  58.689999

# %%
"""
predict closing price fo apple stock for 12/18/2019

get the quote
"""
#apple_quote = web.DataReader('AAPL',data_source='yahoo',start='2012-01-01',end='2019-12-17')
##create a new dataframe

new_df = dataset.copy()
#get last 60days closing values and convert datframe to an array
last_60_days = new_df[-60:].values #converts to array
#scale data
last_60_days_scaled = scaler.transform(last_60_days)
#realreate empty list
x_test = []
#append last 60 days to x_test
x_test.append(last_60_days_scaled)
#conert x_test to a numpy array
x_test = np.array(x_test)
# #reshape the data
x_test = np.reshape(x_test, (x_test.shape[0],x_test.shape[1],1))
#get the predcited scaled price
pred_price = model.predict(x_test)
#undo the scaling 
pred_price = scaler.inverse_transform(pred_price) 
#print predcied price
#what model thinks predcited price will be for 12/18/2019
#the actual prcie was $69.94
#AMZN: 1,784.03
#AMGN: 241.94
print(pred_price)
# Out:
# [[57.408066]]
